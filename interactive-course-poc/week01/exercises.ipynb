# %% [markdown]
# # Week 1: Exercises
#
# Welcome to the Week 1 exercises! These exercises will help you practice what you've learned. Each exercise includes automatic checking so you'll get instant feedback.
#
# ```{admonition} How to Use These Exercises
# :class: tip
# 1. Click the 🚀 button at the top and select "Live Code" to activate interactive mode
# 2. Write your solution in the code cell
# 3. Run the cell to see if your solution is correct
# 4. If you see "✓ Correct!", you've got it! If not, try again.
# ```

# %% [markdown]
# ## Exercise 1: Hello, Python!
#
# **Task:** Create a variable called `greeting` and assign it the string value `"Hello, Python!"`. Then print it.
#
# ```{admonition} Hint
# :class: hint, dropdown
# Remember to use quotes around the text, and use the `print()` function to display it.
# ```

# %%
# Write your code here
greeting = # Your code here

# Print the greeting
print(greeting)

# Auto-check (don't modify this part)
try:
    assert 'greeting' in dir(), "❌ You need to create a variable called 'greeting'"
    assert greeting == "Hello, Python!", f"❌ Expected 'Hello, Python!' but got '{greeting}'"
    print("\n✓ Correct! Well done!")
except AssertionError as e:
    print(f"\n{e}")
except Exception as e:
    print(f"\n❌ Error: {e}")

# %% [markdown]
# ## Exercise 2: Data Types
#
# **Task:** Create three variables:
# - `my_name` with your name as a string
# - `my_age` with your age as an integer
# - `my_height` with your height in meters as a float (e.g., 1.75)
#
# ```{admonition} Hint
# :class: hint, dropdown
# Strings use quotes, integers are whole numbers without quotes, and floats are decimal numbers.
# ```

# %%
# Write your code here
my_name = # Your code here
my_age = # Your code here
my_height = # Your code here

# Auto-check (don't modify this part)
try:
    assert 'my_name' in dir(), "❌ You need to create a variable called 'my_name'"
    assert 'my_age' in dir(), "❌ You need to create a variable called 'my_age'"
    assert 'my_height' in dir(), "❌ You need to create a variable called 'my_height'"
    
    assert isinstance(my_name, str), f"❌ 'my_name' should be a string, but got {type(my_name).__name__}"
    assert isinstance(my_age, int), f"❌ 'my_age' should be an integer, but got {type(my_age).__name__}"
    assert isinstance(my_height, float), f"❌ 'my_height' should be a float, but got {type(my_height).__name__}"
    
    print(f"Name: {my_name} (type: {type(my_name).__name__})")
    print(f"Age: {my_age} (type: {type(my_age).__name__})")
    print(f"Height: {my_height} (type: {type(my_height).__name__})")
    print("\n✓ Correct! All variables have the right types!")
except AssertionError as e:
    print(f"\n{e}")
except Exception as e:
    print(f"\n❌ Error: {e}")

# %% [markdown]
# ## Exercise 3: F-String Formatting
#
# **Task:** Using the variables from Exercise 2, create an f-string that prints:
# ```
# My name is [name], I am [age] years old and [height] meters tall.
# ```
#
# Store this in a variable called `intro` and print it.
#
# ```{admonition} Hint
# :class: hint, dropdown
# Remember to use `f"..."` and put variables inside curly braces `{variable_name}`.
# ```

# %%
# Use the variables from Exercise 2 (or define them again)
my_name = "Alex"  # Change these!
my_age = 20
my_height = 1.75

# Write your code here
intro = # Your f-string here

print(intro)

# Auto-check (don't modify this part)
try:
    assert 'intro' in dir(), "❌ You need to create a variable called 'intro'"
    assert isinstance(intro, str), "❌ 'intro' should be a string"
    assert my_name in intro, f"❌ The intro should include your name '{my_name}'"
    assert str(my_age) in intro, f"❌ The intro should include your age '{my_age}'"
    assert str(my_height) in intro, f"❌ The intro should include your height '{my_height}'"
    print("\n✓ Correct! Great use of f-strings!")
except AssertionError as e:
    print(f"\n{e}")
except Exception as e:
    print(f"\n❌ Error: {e}")

# %% [markdown]
# ## Exercise 4: String Methods
#
# **Task:** Given the messy input below, use string methods to:
# 1. Remove whitespace from both ends
# 2. Convert to title case
# 3. Store the result in a variable called `clean_name`
#
# ```{admonition} Hint
# :class: hint, dropdown
# You can chain methods together: `variable.method1().method2()`
# ```

# %%
# Given messy input
messy_input = "   harry potter   "

# Write your code here
clean_name = # Your code here

print(f"Original: '{messy_input}'")
print(f"Cleaned: '{clean_name}'")

# Auto-check (don't modify this part)
try:
    assert 'clean_name' in dir(), "❌ You need to create a variable called 'clean_name'"
    assert clean_name == "Harry Potter", f"❌ Expected 'Harry Potter' but got '{clean_name}'"
    print("\n✓ Correct! You've mastered string methods!")
except AssertionError as e:
    print(f"\n{e}")
except Exception as e:
    print(f"\n❌ Error: {e}")

# %% [markdown]
# ## Exercise 5: Math Operations
#
# **Task:** Calculate the following and store each result in the specified variable:
# - `sum_result`: The sum of 15 and 27
# - `product_result`: The product of 8 and 9
# - `power_result`: 5 to the power of 3 (5³)
# - `division_result`: 100 divided by 8
#
# ```{admonition} Hint
# :class: hint, dropdown
# Use `+`, `*`, `**`, and `/` operators. Remember that `**` is for exponents!
# ```

# %%
# Write your code here
sum_result = # Your code here
product_result = # Your code here
power_result = # Your code here
division_result = # Your code here

# Auto-check (don't modify this part)
try:
    assert sum_result == 42, f"❌ Sum should be 42, got {sum_result}"
    assert product_result == 72, f"❌ Product should be 72, got {product_result}"
    assert power_result == 125, f"❌ Power should be 125, got {power_result}"
    assert division_result == 12.5, f"❌ Division should be 12.5, got {division_result}"
    
    print(f"Sum: {sum_result}")
    print(f"Product: {product_result}")
    print(f"Power: {power_result}")
    print(f"Division: {division_result}")
    print("\n✓ Correct! You're a math wizard!")
except AssertionError as e:
    print(f"\n{e}")
except Exception as e:
    print(f"\n❌ Error: {e}")

# %% [markdown]
# ## Exercise 6: Type Conversion
#
# **Task:** You have two string variables representing numbers. Convert them to integers, add them together, and store the result in `total`.
#
# ```{admonition} Hint
# :class: hint, dropdown
# Use the `int()` function to convert strings to integers.
# ```

# %%
# Given string numbers
num1 = "25"
num2 = "17"

# Write your code here
total = # Your code here

print(f"Result: {total}")
print(f"Type: {type(total)}")

# Auto-check (don't modify this part)
try:
    assert 'total' in dir(), "❌ You need to create a variable called 'total'"
    assert total == 42, f"❌ Expected 42 but got {total}"
    assert isinstance(total, int), f"❌ 'total' should be an integer, but got {type(total).__name__}"
    print("\n✓ Correct! You understand type conversion!")
except AssertionError as e:
    print(f"\n{e}")
except Exception as e:
    print(f"\n❌ Error: {e}")

# %% [markdown]
# ## Exercise 7: Create Your Own Function
#
# **Task:** Create a function called `greet_user` that:
# - Takes one parameter: `name`
# - Returns a greeting string in the format: `"Hello, [name]! Welcome to Python."`
#
# ```{admonition} Hint
# :class: hint, dropdown
# Use `def` to define a function, and `return` to send back a value. Use an f-string for formatting!
# ```

# %%
# Write your function here
def greet_user(name):
    # Your code here
    pass  # Remove this line when you add your code

# Test your function
print(greet_user("Alice"))

# Auto-check (don't modify this part)
try:
    assert callable(greet_user), "❌ 'greet_user' should be a function"
    
    result1 = greet_user("Alice")
    assert result1 == "Hello, Alice! Welcome to Python.", f"❌ Expected 'Hello, Alice! Welcome to Python.' but got '{result1}'"
    
    result2 = greet_user("Bob")
    assert result2 == "Hello, Bob! Welcome to Python.", f"❌ Your function should work for any name"
    
    print("\n✓ Correct! You can now create functions!")
except AssertionError as e:
    print(f"\n{e}")
except Exception as e:
    print(f"\n❌ Error: {e}")

# %% [markdown]
# ## Exercise 8: Advanced Function
#
# **Task:** Create a function called `calculate_rectangle_area` that:
# - Takes two parameters: `length` and `width`
# - Calculates the area (length × width)
# - Returns the result
#
# ```{admonition} Hint
# :class: hint, dropdown
# Area of rectangle = length × width. Use the `*` operator and `return` the result.
# ```

# %%
# Write your function here
def calculate_rectangle_area(length, width):
    # Your code here
    pass  # Remove this line when you add your code

# Test your function
print(f"Area of 5x3 rectangle: {calculate_rectangle_area(5, 3)}")

# Auto-check (don't modify this part)
try:
    assert callable(calculate_rectangle_area), "❌ 'calculate_rectangle_area' should be a function"
    
    assert calculate_rectangle_area(5, 3) == 15, "❌ Area of 5×3 should be 15"
    assert calculate_rectangle_area(10, 4) == 40, "❌ Area of 10×4 should be 40"
    assert calculate_rectangle_area(2.5, 4) == 10.0, "❌ Your function should work with floats too"
    
    print("\n✓ Correct! You're mastering functions!")
except AssertionError as e:
    print(f"\n{e}")
except Exception as e:
    print(f"\n❌ Error: {e}")

# %% [markdown]
# ## Challenge Exercise: Temperature Converter
#
# **Task:** Create a function called `celsius_to_fahrenheit` that:
# - Takes one parameter: `celsius` (temperature in Celsius)
# - Converts it to Fahrenheit using the formula: `F = (C × 9/5) + 32`
# - Returns the Fahrenheit temperature rounded to 1 decimal place
#
# ```{admonition} Hint
# :class: hint, dropdown
# Use the `round()` function: `round(value, 1)` rounds to 1 decimal place.
# ```

# %%
# Write your function here
def celsius_to_fahrenheit(celsius):
    # Your code here
    pass  # Remove this line when you add your code

# Test your function
print(f"0°C = {celsius_to_fahrenheit(0)}°F")
print(f"100°C = {celsius_to_fahrenheit(100)}°F")

# Auto-check (don't modify this part)
try:
    assert callable(celsius_to_fahrenheit), "❌ 'celsius_to_fahrenheit' should be a function"
    
    assert celsius_to_fahrenheit(0) == 32.0, "❌ 0°C should be 32°F"
    assert celsius_to_fahrenheit(100) == 212.0, "❌ 100°C should be 212°F"
    assert celsius_to_fahrenheit(37) == 98.6, "❌ 37°C should be 98.6°F"
    assert celsius_to_fahrenheit(-40) == -40.0, "❌ -40°C should be -40°F"
    
    print("\n✓ Correct! You've mastered the challenge exercise!")
except AssertionError as e:
    print(f"\n{e}")
except Exception as e:
    print(f"\n❌ Error: {e}")

# %% [markdown]
# ## Congratulations!
#
# ```{admonition} Well Done!
# :class: tip
# You've completed all the Week 1 exercises! You now have hands-on experience with:
# - Variables and data types
# - String formatting and methods
# - Mathematical operations
# - Type conversion
# - Creating and using functions
#
# Don't worry if you encountered errors - they're a natural part of learning to code. The important thing is that you kept trying until you got it right!
#
# Ready for Week 2? Keep up the great work!
# ```

# %% [markdown]
# # Week 1: Python Fundamentals
#
# **Welcome to your first Python session!** This week we're going to cover some fundamental Python programming skills.
#
# ```{admonition} Interactive Learning
# :class: tip
# Click the 🚀 button at the top of the page and select "Live Code" to run code directly in your browser! You can modify any example and see the results immediately.
# ```

# %% [markdown]
# ## 1.1 Simple Python Program
#
# First we write a simple Python program that prints `Hello World`.

# %%
print("Hello World")

# %% [markdown]
# You will notice we used a Python built-in function `print()`. It can take any valid argument/input. Our argument was `"Hello World"`. We could have done the same thing with a little variation.

# %%
print('Hello World')

# %% [markdown]
# Notice here that we got the same results. It printed `Hello World`. But do you see the difference? We used single quotes `' '` instead of double quotes `" "`.
#
# We can also print numbers.

# %%
print(2)

# %%
print(100)

# %% [markdown]
# ```{admonition} Try it yourself!
# :class: note
# Try printing your name or your favorite number. Modify the code above and run it!
# ```

# %% [markdown]
# ## 1.2 Values and Types
#
# A **value** is one of the basic things a program works with, like a letter or a number. Notice that we printed `Hello World`, `2` and `100`. These values belong to different **types**: `2` is an *integer*, and `"Hello, World!"` is a *string*, so called because it contains a "string" of letters. You (and Python) can identify strings because they are enclosed in quotation marks. Just use the `type()` function and Python will tell you the type.

# %%
type('Hello World')

# %%
type(2)

# %%
type(2.0)

# %%
type(2.2)

# %%
type('2')

# %% [markdown]
# ## 1.3 Variables
#
# One of the most powerful features of a programming language is the ability to manipulate **variables**. A variable is a name that refers to a value. An **assignment statement** creates new variables and gives them values:

# %%
message = 'And now for something completely different'
some_number = 2

# %% [markdown]
# The example above makes 2 assignments. The first assigns a string to a new variable named `message`; the second assigns the integer `2` to `some_number`. To display the value of a variable, you can use a print statement:

# %%
print(message)

# %%
print(some_number)

# %% [markdown]
# The type of a variable is the type of the value it refers to.

# %%
type(message)

# %%
type(some_number)

# %% [markdown]
# ## 1.4 Print Function and Variables
#
# In the `print()` function we can introduce variables. Let's say we create a variable called `name`.

# %%
name = "Nasreen"

# %%
print("Hello", name)

# %% [markdown]
# In the code above we used two inputs to the print function `"Hello"` and `name`. The second input is the `name` variable we created where we stored the value `Nasreen`. We could have gotten the same result by concatenating. See the following.

# %%
print("Hello" + name)

# %% [markdown]
# But the output is not desirable as there is no space (or *white-space*) between Hello and Nasreen. We can fix that by putting a white space in `"Hello"` by typing `"Hello "`.

# %%
print("Hello " + name)

# %% [markdown]
# ### 1.4.1 Input Function
#
# ```{admonition} Note about Interactive Mode
# :class: warning
# The `input()` function works differently in interactive mode. In the live code version, you can modify the code to assign values directly instead of waiting for keyboard input. For example, change `name_input = input("What is your name? ")` to `name_input = "Your Name"`.
# ```
#
# Now let's see how we could get some user input and then print Hello to the user.

# %%
# For interactive mode, you can replace the input() with a direct assignment:
# name_input = "Sakib"
name_input = "Sakib"  # Try changing this to your name!
print("Hello", name_input)

# %% [markdown]
# We successfully managed to say hello to the user! Here we created a variable `name_input` where we stored the name. The `input()` function is a built-in Python function that gets input from the keyboard. When this function is called, the program stops and waits for the user to type something. When the user presses Return or Enter, the program resumes and input returns what the user typed as a string.

# %% [markdown]
# ### 1.4.2 Formatting Strings
#
# Probably the most elegant way to use strings would be as follows:

# %%
name_input = "Sakib"
print(f"hello {name_input}")

# %% [markdown]
# Notice the `f` in `print(f"hello {name_input}")`. This `f` is a special indicator to Python to treat this string a special way, different than previous approaches we have illustrated in this lecture. Expect that you will be using this style of strings quite frequently in this course. In the example above we used curly brackets `{}`. When the print function is called, Python is going to look for the variable inside the curly bracket and print the value of that variable.

# %% [markdown]
# ### 1.4.3 Removing Unnecessary White-space
#
# You should never expect your user will cooperate as intended. Therefore, you will need to ensure that the input of your user is corrected or checked. It turns out that built into strings is the ability to remove whitespace from a string.
#
# By utilizing the method `strip` on `name_input` as `name_input_remove = name_input.strip()`, it will strip all the whitespaces on the left and right of the user's input.

# %%
name_input = "   sakib   "  # Notice the extra spaces!
name_input_removespace = name_input.strip()
print("hello", name_input_removespace)

# %% [markdown]
# ### 1.4.4 Title
#
# Using the `title` method, it would title case the user's name:

# %%
# Ask the user for their name
name = "sakib"

# Remove whitespace from the str
name = name.strip()

# Capitalize the first letter of each word
name = name.title()

# Print the output
print(f"Hello, {name}")

# %% [markdown]
# Notice that you can modify your code to be more efficient:

# %%
# Ask the user for their name, remove whitespace and capitalize
name = "sakib"
name = name.strip().title()

# Print the output
print(f"Hello, {name}")

# %% [markdown]
# We could even go further!

# %%
# Ask the user for their name, remove whitespace and capitalize in one line
name = "sakib".strip().title()

# Print the output
print(f"hello, {name}")

# %% [markdown]
# ### 1.4.5 Comments
#
# Comments are a way for programmers to track what they are doing in their programs and even inform others about their intentions for a block of code. In short, they are notes for yourself and others that will see your code! We have been using them in the previous couple of cells by putting a hashtag sign `#`. When Python sees this hashtag it doesn't execute that line. You can add comments to your program to be able to see what it is that your program is doing.

# %% [markdown]
# ## 1.5 Integers or int
#
# In Python, an integer is referred to as an `int`. In the world of mathematics, we are familiar with `+`, `-`, `*`, `/`, and `%` operators. That last operator `%` or modulo operator may not be very familiar to you.
#
# Let's do some calculations:

# %%
2 + 3

# %%
a = 2
b = 3
print(a + b)

# %%
print(a / b)

# %%
print(a * b)

# %% [markdown]
# Now if you want to use exponents like calculating $2^3$ or $2 \times 2 \times 2$. You need to use `2**3`.

# %%
2**3

# %%
print(a**b)

# %% [markdown]
# ### 1.5.1 Converting to int
#
# If you want to convert a string to integer we just use the `int()` function.

# %%
c = '2'
d = '3'
c1 = int(c)
d1 = int(d)
print(c1 * d1)

# %% [markdown]
# The following converts float to int:

# %%
z = 3.2
z1 = int(3.2)
print(z1)

# %% [markdown]
# We have been doing some calculations with Python. But we can make it more interactive by using `input()`:

# %%
# For interactive mode, replace input() with direct values:
x = 1  # Change this value!
y = 2  # Change this value!
z = int(x) + int(y)
print(z)

# %% [markdown]
# ## 1.6 Creating Your Own Function
#
# So far, we have only been using the functions that come with Python, but it is also possible to add new functions. A **function definition** specifies the name of a new function and the sequence of statements that execute when the function is called. Once we define a function, we can reuse the function over and over throughout our program. We can use Python's keyword `def` to create our own function.

# %%
def print_lyrics():
    print("I'm a lumberjack, and I'm okay.")
    print('I sleep all night and I work all day.')

# %% [markdown]
# `def` is a keyword that indicates that this is a function definition. The name of the function is `print_lyrics`. The rules for function names are the same as for variable names: letters, numbers and some punctuation marks are legal, but the first character can't be a number. You can't use a keyword as the name of a function, and you should avoid having a variable and a function with the same name.
#
# The empty parentheses `()` after the name indicate that this function doesn't take any arguments. Later we will build functions that take arguments as their inputs. The first line of the function definition is called the **header**; the rest is called the **body**. The header has to end with a colon `:` and the body has to be indented. By convention, the indentation is always four spaces.
#
# Let's see what kind of object `print_lyrics` is:

# %%
type(print_lyrics)

# %% [markdown]
# No surprise! The value of `print_lyrics` is a function object, which has type "function".
#
# Now how do we call the function? The syntax for calling the new function is the same as for built-in functions:

# %%
print_lyrics()

# %% [markdown]
# Now let's create a function with inputs. Here we define a function `add_two_things` with two inputs `a` and `b`.

# %%
def add_two_things(a, b):
    addition = a + b
    print(addition)

# %% [markdown]
# Now let's call the function. I want to add 3 and 2.

# %%
add_two_things(3, 2)

# %% [markdown]
# We do get the desired result. But if we want to use this function somewhere else like maybe multiply with 3: `add_two_things(3,2)*3`, you will run into an error. To fix this we need our function to **return** a value. So we use `return` instead of `print()`:

# %%
def add_two_things(a, b):
    addition = a + b
    return addition

# %% [markdown]
# Now if we try to run the same operation: `add_two_things(3,2)*3`, we have no problem!

# %%
add_two_things(3, 2) * 3

# %% [markdown]
# Now let's make this calculator more interactive:

# %%
def add_two_things(a, b):
    addition = a + b
    return addition

# For interactive mode, assign values directly:
a = 5  # Try changing these values!
b = 7
result = add_two_things(a, b)
print(f"The sum of {a} and {b} is {result}")

# %% [markdown]
# ```{admonition} Congratulations!
# :class: tip
# You've completed Week 1! You now know how to:
# - Print values to the screen
# - Work with different data types (strings, integers, floats)
# - Create and use variables
# - Format strings elegantly with f-strings
# - Perform mathematical operations
# - Create your own functions
#
# Ready to test your knowledge? Move on to the [Week 1 Exercises](exercises.ipynb)!
# ```
